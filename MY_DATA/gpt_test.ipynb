# %%
import pandas as pd

df = pd.read_csv('gloss_from_book.csv')
testset = []
for i in range(len(df)):
    # testset.append((df['spoken'][i].strip(), ''))
    print(df['gloss'][i].strip())
# testset
# Out:
# 안녕 ? 만나다 반갑다 . 나 농인 .
# 안녕 ? 만나다 반갑다 . 나 청인 .
# 당신 이름 무엇 ?
# 당신 농인 ?
# 아니오 . 나 청인 .
# 고맙다 . 미안하다 . 괜찮다 .
# 수고 다음 또 만나다
# 나이 몇 ? 나 20 .
# 나 같다 . 나 20 .
# 우리 둘 친하게 지내다 괜찮다 .
# 괜찮다 OK 좋다 .
# 휴대폰 번호 무엇 ?
# 나 휴대폰 번호 010-2456-2642 .
# 앞으로 자주 문자메시지를 주고받다 연락하다 OK .
# 당신 1살 위 .
# 나 2살 아래 .
# 그 신발 돈 얼마 ?
# 4만 5천 .
# 같다 전공 친구 .
# 당신 전공 무엇 ?
# 나 전공 무엇 수화 통역 .
# 가족 소개 주세요 .
# 나 가족 부모님 오빠 나 4 사람 .
# 나 가족 조부모님 부모님 누나 나 남동생 7사람 .
# 가족 많다 부럽다 .
# 나 전공 사회 행복 .
# 나 특별 교육 공부 .
# 저 사람 같다 전공 선배 .
# 저 사람 동아리 동기 .
# 당신 결혼 끝 ?
# 아니오 . 결혼 아직 .
# 나 태어나다 곳 부산 .
# 부모님 태어나다 곳 부산 같다 ?
# 아니오 . 아버지 대구 어머니 부산 .
# 나 태어나다 곳 천안 .
# 나 태어나다 곳 천안 호두 과자 유명하다 .
# 춘천 닭 갈비 유명하다 전주 비빔밥 유명하다 .
# 우리 둘 함께 전국 맛있다 음식 찾다 여행 출발 어때 ?
# 보성 방문 경험 ?
# 녹차밭 예쁘다 .
# 당신 미국 방문 경험 ?
# 그러나 1 방문 원하다 .
# 좋다 음식 무엇 ?
# 나 비빔밥 좋다 .
# 비빔밥 맛있다 이루다 장소 알다 ?
# 먹다 장소 유명하다 .
# 당신 취미 무엇 ?
# 나 취미 무엇 영화 보다 .
# 요즈음 재미있다 영화 무엇 ?
# 그러나 한국 영화 자막 없다 섭섭하다 .
# 배고프다 . 밥 출발 .
# 나 같다 . 먹다 무엇 ?
# 맵다 김치 끓이다 괜찮다 ?
# 나 맵다 싫다 .
# 좋아하다 운동 무엇 ?
# 수영 탁구 좋아하다 .
# 당신 취미 무엇 ?
# ...

# %%
gpt35_test = [
     ('안녕하십니까? 만나서 반갑습니다. 저는 농인입니다.', '안녕하세요? 만나서 반갑습니다. 저는 농인입니다.'),
     ('안녕하십니까? 만나서 반갑습니다. 저는 청인입니다.', '안녕하세요? 만나서 반갑습니다. 저는 청인입니다.'),
     ('당신의 이름은 무엇입니까?', '당신의 이름은 무엇인가요?'),
     ('당신은 농인입니까?', '당신은 농인이시군요?'),
     ('아니오. 나는 청인입니다.', '아니요, 저는 청인입니다.'),
     ('고맙습니다. 미안합니다. 괜찮습니다.', '고맙습니다. 미안합니다. 괜찮습니다.'),
     ('수고하셨습니다. 다음에 또 뵙겠습니다.', '수고하셨어요. 다음에 또 만나요.'),
     ('나이가 어떻게 되세요? 나는 20살입니다.', '나이가 어떻게 되세요? 저는 20살입니다.'),
     ('저랑 동갑이군요. 나도 20살입니다.', '저도 20살입니다.'),
     ('우리 친하게 지냅시다.', '우리 둘 친하게 지내는 건 좋겠죠.'),
     ('좋아요.', '괜찮아요. OK입니다.'),
     ('휴대폰 번호가 어떻게 되나요?', '휴대폰 번호가 어떻게 되세요?'),
     ('내 휴대폰 번호는 010-2456-2642입니다.', '제 휴대폰 번호는 010-2456-2642입니다.'),
     ('앞으로 자주 연락 나눠요.', '앞으로 자주 문자메시지를 주고 받아 연락하면 좋겠어요.'),
     ('저보다 한 살 더 많으시네요.', '당신은 1살 위이시군요.'),
     ('제가 두 살 더 적습니다.', '나는 2살 아래입니다.'),
     ('그 신발은 얼마입니까?', '그 신발은 얼마에요?'),
     ('4만 5천원입니다.', '그 신발은 4만 5천원이에요.'),
     ('같은 과 친구예요.', '전공이 같은 친구군요.'),
     ('전공이 무엇인가요?', '당신의 전공은 무엇인가요?'),
     ('나는 수화통역을 전공하고 있습니다.', '제 전공은 수화 통역입니다.'),
     ('가족 소개를 해 주세요.', '가족을 소개해주세요.'),
     ('우리 가족은 부모님 오빠 나 모두 4명입니다.', '제 가족은 부모님, 오빠, 그리고 나로 총 4명입니다.'),
     ('우리 가족은 할아버지 할머니 부모님 누나 나 남동생 모두 7명입니다.', '제 가족은 조부모님, 부모님, 누나, 나, 남동생으로 총 7명이에요.'),
     ('가족이 많아 부럽군요.', '가족이 많아서 부럽네요.'),
     ('내 전공은 사회복지입니다.', '제 전공은 사회 행복입니다.'),
     ('내 전공은 특수교육입니다.', '제 특별 교육을 공부하고 있어요.'),
     ('저분은 같은 과 선배입니다.', '저 사람은 제 전공의 선배이에요.'),
     ('저 사람은 동아리 동기입니다.', '저 사람은 동아리 동기에요.'),
     ('당신은 결혼을 했습니까?', '당신은 결혼하셨나요?'),
     ('아니오. 아직 안 했습니다.', '아니요, 아직 결혼하지 않았습니다.'),
     ('내 고향은 부산입니다.', '저는 부산에서 태어났습니다.'),
     ('부모님 고향도 부산입니까?', '부모님도 부산에서 태어나셨습니까?'),
     ('아니오. 아버지 고향은 대구이고 어머니 고향은 부산입니다.', '아니요, 아버지는 대구에서 어머니는 부산에서 태어났습니다.'),
     ('내 고향은 천안입니다.', '저는 천안에서 태어났어요.'),
     ('내 고향 천안은 호두과자가 유명합니다.', '천안에서 태어난 곳이 유명한 호두 과자로 알려져 있어요.'),
     ('춘천에는 닭갈비가 유명하고 전주는 비빔밥이 유명합니다.', '춘천은 닭 갈비로 유명하고 전주는 비빔밥으로 유명해요.'),
     ('우리 함께 전국의 맛있는 음식을 찾아 여행을 떠날까요?', '우리 둘이 함께 전국 맛있는 음식을 찾아 여행을 떠나볼까요?'),
     ('보성에 가본 적 있나요?', '보성을 방문한 적 있나요?'),
     ('녹차 밭이 무척 예뻤어요.', '녹차밭이 아름답다고 하더라고요.'),
     ('미국에 가본 적 있어요?', '당신은 미국을 방문한 적이 있나요?'),
     ('하지만 꼭 한번 가보고 싶어요.', '하지만 아직 한 번도 방문해보지 못했습니다.'),
     ('좋아하는 음식이 무엇인가요?', '어떤 음식을 좋아하세요?'),
     ('나는 비빔밥을 좋아해요.', '저는 비빔밥을 좋아해요.'),
     ('비빔밥 맛있는 음식점을 알고 있나요?', '비빔밥을 맛있게 먹을 수 있는 장소를 아시나요?'),
     ('식당이 유명해요.', '유명한 먹는 곳이 많다고 하더라고요.'),
     ('취미가 뭐예요?', '당신의 취미는 무엇인가요?'),
     ('내 취미는 영화감상이에요.', '저는 영화를 보는 것을 즐겨해요.'),
     ('요즈음 재미있는 영화가 있나요?', '요즘에 어떤 재미있는 영화가 있나요?'),
     ('하지만 한국 영화는 자막이 없어서 안타까워요.', '하지만 한국 영화는 자막이 없어서 아쉽네요.'),
     ('배고파요. 밥 먹으러 갑시다.', '배고파요. 밥을 먹으러 가요.'),
     ('저도요. 뭐 먹으러 갈까요?', '제가도요. 무슨 음식을 먹을까요?'),
     ('얼큰한 김치찌개 어때요?', '매운 김치찌개를 끓이는 건 어떠세요?'),
     ('나는 매운 음식을 싫어해요.', '저는 매운 음식을 좋아하지 않아요.'),
     ('좋아하는 운동이 뭐예요?', '운동을 좋아하나요?'),
     ('나는 수영과 탁구를 좋아해요.', '수영과 탁구를 좋아해요.'),
     ('취미가 무엇인가요?', '당신의 취미는 무엇인가요?'),
     ('내 취미는 독서와 음악감상이에요.', '저는 독서와 음악 듣기를 좋아해요.'),
     ('4월 20일이 무슨 날인가요?', '4월 20일은 어떤 날인가요?'),
     ('장애인의 날이에요.', '장애인의 날이에요.'),
     ('그렇군요! 농인의 날은 언제인가요?', '그렇군요! 농인의 날은 언제인가요?'),
     ('6월 3일이에요.', '6월 3일이에요.'),
     ('10시 30분이에요.', '아침 10시 30분부터 시작돼요.'),
     ('11시에 수업이 시작합니다. 나 먼저 가볼게요.', '11시에 공부를 시작하겠어요. 나 먼저 갈게요.'),
     ('알았어요. 다음에 또 만나요.', '알겠어요. 다음에 또 만나요.'),
     ('생일이 언제인가요?', '당신은 언제 태어났나요?'),
     ('8월 18일이에요.', '8월 18일에 태어났어요.'),
     ('5월 15일은 무슨 날인가요?', '5월 15일은 어떤 날인가요?'),
     ('스승의 날이에요.', '교사의 날이에요. '),
     ('오늘은 봄비가 내리고 있어요.', '오늘은 봄비가 내리고 있어요.'),
     ('비가 그치면 날씨가 따뜻해질 겁니다.', '비가 멈추면 날씨가 따뜻해질 것 같아요.'),
     ('며칠 있으면 꽃이 피겠군요?', '몇 일을 기다리면 꽃이 피어날까요?'),
     ('나는 봄에 피는 개나리를 좋아합니다.', '저는 봄에 노란 꽃을 좋아해요.'),
     ('어떤 계절을 좋아하나요?', '어떤 계절을 좋아하시나요?'),
     ('맑은 하늘과 단풍이 멋진 가을이 좋습니다.', '가을이 좋습니다. 하늘도 맑고, 빨간 잎들도 멋집니다.'),
     ('나는 눈 내리는 겨울이 좋습니다.', '겨울에 눈이 좋습니다.'),
     ('우리나라의 사철은 나름대로 운치 있어 모두 좋습니다.', '한국의 계절 모두 멋집니다.'),
     ('하늘이 흐린 걸 보니 비가 올 모양이에요.', '하늘에 구름이 끼고 비도 내리겠죠.'),
     ('우산을 미리 준비하세요.', '우산을 미리 준비해 주세요.'),
     ('날씨가 추우니까 옷을 두둑하게 입으세요.', '날씨가 춥습니다. 두꺼운 옷을 입는 것을 추천합니다.'),
     ('지금 어디에 가요?', '어디로 가실 건가요?'),
     ('도서관에 가고 있어요.', '책을 읽다가 집에 가요.'),
     ('도서관에는 무슨 일로 가나요?', '책을 읽다가 집에 가는 이유는 무엇인가요?'),
     ('다음 주가 시험이라 공부하러 갑니다.', '다음 주에 시험 때문에 공부를 해야 해서요.'),
     ('무슨 일 하세요?', '당신의 직업은 무엇인가요?'),
     ('농아인협회에서 수화통역사로 일합니다.', '저는 농인 협회에서 수화 통역을 하는 사람입니다.'),
     ('수화통역사는 무슨 일을 하나요?', ''),
     ('농인과 청인의 의사소통을 지원합니다.', '농인과 청인 간의 대화를 돕는 사람입니다.'),
     ('과제 다 했니?', '숙제는 끝났나요?'),
     ('과제라니? 아이쿠. 깜빡 잊고 있었어.', '숙제가 뭐에요? 아이쿠, 잊어버렸네요.'),
     ('장래희망이 무엇인가요?', '미래에 원하는 희망은 무엇인가요?'),
     ('나는 유치원선생님이 되고 싶어요.', '저는 유치원 교사가 되고 싶어요.'),
     ('어린이들을 좋아하거든요.', '아이들을 좋아해요.'),
     ('당신에게 잘 어울리는 거 같아요.', '당신은 잘 어울립니다.'),
     ('내일이 여자친구 생일이에요.', '내일은 여자 친구의 생일이에요.'),
     ('선물은 준비했나요?', '선물 준비는 끝났어요?'),
     ('아직 준비를 못했어요. 뭐가 좋을까요?', '아직 준비를 안 했어요. 어떤 선물이 좋을까요?'),
     ('꽃과 화장품은 어때요?', '꽃이나 화장품은 어떨까요?'),
     ('동생은 잘 지내고 있나요?', '동생은 잘 지내나요?'),
     ('진동알람시계를 선물해 주는 건 어떄요?', '진동 시계를 선물해보는 건 어떨까요?'),
     ('찾으시는 물건이 있나요?', '어떤 물건이 원하시나요?'),
     ('우선 둘러볼게요.', '먼저 구경부터 해보세요.'),
     ('이 구두가 마음에 들어요. 270사이즈 주세요.', '이 구두 마음에 들어요. 270 사이즈 주세요.'),
     ('죄송합니다. 270사이즈는 다 팔리고 없습니다.', '미안해요, 270 사이즈는 다 떨어졌네요.'),
     ('천안에서 대전까지 가는 가장 빠른 방법은 무엇인가요?', '천안부터 대전까지 가장 빠른 방법은 무엇인가요?'),
     ('KTX는 비싸지 않나요?', 'KTX는 비싸요?'),
     ('농인은 50% 할인이 되기 때문에 부담이 덜합니다.', '농인 50% 할인을 받을 수 있어서 조금 괜찮아요.'),
     ('이번 여름방학 계획이 어떻게 되나요?', '여름 방학 계획이 어떻게 되나요?'),
     ('친구들과 함께 자전거 여행을 하기로 했어요.', '친구와 함께 자전거 여행을 결정했어요.'),
     ('어디로 가나요?', '여행의 목적은 어디인가요?'),
     ('서울에서 출발하여 부산까지 갑니다.', '서울에서 출발해서 부산까지 가려고 해요.'),
     ('운전할 수 있어요?', '운전할 수 있나요?'),
     ('아니요. 지금 배우고 있어요. 그런데 주차가 가장 어려운 것 같아요.', '아직 배우는 중이지만, 주차가 가장 어려운 것 같아요.'),
     ('꼭 합격하시길 바랍니다.', '합격하기를 화이팅하겠습니다.'),
     ('소화가 잘 안 되고 머리가 아파요.', '소화가 안 돼서 머리가 아파요.'),
     ('병원에는 다녀왔어요?', '병원에 가서 어떤 진료를 받았나요? '),
     ('이번 수업 휴강이래요.', '오늘은 공부를 쉬는 날이에요.'),
     ('왜요 ?', '왜 그런가요?'),
     ('교수님께서 맹장수술을 하고 입원해 계신대요.', '교사 맹장 수술을 받았기 때문에 입원 중이에요.'),
     ('우리 함께 병문안 갑시다.', '함께 병원에서 위로해 드릴게요.'),
     ('어제 치통 때문에 밤새 잠을 한숨도 못 잤어요.', '어제 치아가 아파서 잠을 제대로 못 잤어요. '),
     ('저런.. 얼른 병원에 가서 진찰을 받아보세요.', '병원에서 빨리 진찰 받아보세요.'),
     ('무엇보다 건강이 제일 중요합니다.', '건강은 가장 중요합니다. 무엇보다 건강하세요.'),
     ('식사를 거르지 말고 꼬박꼬박 챙겨먹고 적당한 운동을 하면 건강에 도움이 될 거 에요.', '밥 약속을 취소하지 말고 꼭 밥을 먹고, 적당히 운동해서 건강에 도움을 받아주세요.')
]

import mecab_ko as Mecab
from nltk.translate.bleu_score import sentence_bleu
import numpy as np

mecab = Mecab.Tagger('-Owakati')
SCORE1, SCORE2, SCORE3, SCORE4, SCORET = [], [], [], [], []

for i in gpt35_test:
     gt_text, output_text = i
     gtext = mecab.parse(gt_text).split()
     outputtext = mecab.parse(output_text).split()
     SCORE1.append(sentence_bleu([gtext], outputtext, weights=(1, 0, 0, 0)))
     SCORE2.append(sentence_bleu([gtext], outputtext, weights=(0, 1, 0, 0)))
     SCORE3.append(sentence_bleu([gtext], outputtext, weights=(0, 0, 1, 0)))
     SCORE4.append(sentence_bleu([gtext], outputtext, weights=(0, 0, 0, 1)))
     SCORET.append(sentence_bleu([gtext], outputtext))
BLEU1, BLEU2, BLEU3, BLEU4, BLEUT = np.mean(SCORE1), np.mean(SCORE2), np.mean(SCORE3), np.mean(SCORE4), np.mean(SCORET)
print('BLEU1: {:.3f}, BLEU2: {:.3f}, BLEU3: {:.3f}, BLEU4: {:.3f}, BLEUT: {:.3f}'.format(BLEU1, BLEU2, BLEU3, BLEU4, BLEUT))
# Out:
# BLEU1: 0.525, BLEU2: 0.320, BLEU3: 0.239, BLEU4: 0.176, BLEUT: 0.228
# /home/dodant/anaconda3/envs/gloss_translate/lib/python3.8/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/dodant/anaconda3/envs/gloss_translate/lib/python3.8/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/dodant/anaconda3/envs/gloss_translate/lib/python3.8/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# ...
